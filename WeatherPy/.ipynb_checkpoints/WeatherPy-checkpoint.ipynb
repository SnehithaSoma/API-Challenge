# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %% [markdown]
# Observable Trends:
#
# 1. The first trend observed is, the climate in southern hemisphere tends to be milder than those of the similar latitudes in the northern hemisphere. This is because the Southern Hemisphere has significantly more ocean and much less land; water heats up and cools down more slowly than land.
# 2. The second trend that I could analyse is, highest temperature is found at 0 latitude and as the latidude increases or decreases, temperature drops. This happens as equatorial region receives sunlight straight with less or no angle due to curvature shape of earth.
# 3. The third observed trend is that,the speed of the wind is controlled by the strength of the air pressure gradient, the stronger the pressure gradient the higher the wind speed. Latitude doesnot have strong influence on thee wind speed.

# %%
# Importing Dependencies 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import datetime
import scipy.stats as st
from scipy.stats import linregress

# Importing API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
#Creating lists to hold lat & lon values and cities 
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Printing the city count to confirm enough count
len(cities)
# Out:
# 618

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#Creating all the list varaibles to hold all the data from the API responses accordingly
city_name_list = []
cloudiness_list = []
country_list = []
date_list = []
humidity_list = []
lat_list = []
lng_list = []
max_temp_list = []
wind_speed_list = []
index_counter = 0
set_counter = 1

print("Beginning Data Retrieval ")
print("-----------------------------")


base_url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{base_url}appid={weather_api_key}&units={units}&q="


# For each city name in cities list, doing the  below things
for index, city in enumerate(cities, start = 1):
    try:
        response = requests.get(query_url + city).json()
        city_name_list.append(response["name"])
        cloudiness_list.append(response["clouds"]["all"])
        country_list.append(response["sys"]["country"])
        date_list.append(response["dt"])
        humidity_list.append(response["main"]["humidity"])
        lat_list.append(response["coord"]["lat"])
        lng_list.append(response["coord"]["lon"])
        max_temp_list.append(response['main']['temp_max'])
        wind_speed_list.append(response["wind"]["speed"])
        if index_counter > 49:
            index_counter = 0
            set_counter = set_counter + 1
    
        else:
            index_counter = index_counter + 1
            
        print(f"Processing Record {index_counter} of Set {set_counter} : {city}") 
  
    except(KeyError, IndexError):
        print("City not found. Skipping...")

print("-----------------------------")
print("Data Retrieval Complete")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 : saldanha
# Processing Record 2 of Set 1 : hithadhoo
# Processing Record 3 of Set 1 : puerto colombia
# Processing Record 4 of Set 1 : mecca
# Processing Record 5 of Set 1 : lagoa
# City not found. Skipping...
# Processing Record 6 of Set 1 : namibe
# Processing Record 7 of Set 1 : faanui
# Processing Record 8 of Set 1 : rikitea
# Processing Record 9 of Set 1 : lampang
# Processing Record 10 of Set 1 : sao borja
# Processing Record 11 of Set 1 : severo-kurilsk
# Processing Record 12 of Set 1 : klaksvik
# Processing Record 13 of Set 1 : ganzhou
# Processing Record 14 of Set 1 : hermanus
# Processing Record 15 of Set 1 : rubiataba
# Processing Record 16 of Set 1 : atuona
# Processing Record 17 of Set 1 : zarubino
# Processing Record 18 of Set 1 : albany
# Processing Record 19 of Set 1 : kapaa
# Processing Record 20 of Set 1 : poya
# Processing Record 21 of Set 1 : flinders
# Processing Record 22 of Set 1 : southbridge
# Processing Record 23 of Set 1 : adrar
# Processing Record 24 of Set 1 : el naranjo
# Processing Record 25 of Set 1 : road town
# Processing Record 26 of Set 1 : charters towers
# Processing Record 27 of Set 1 : saskylakh
# Processing Record 28 of Set 1 : saint george
# Processing Record 29 of Set 1 : ushuaia
# Processing Record 30 of Set 1 : ponta do sol
# Processing Record 31 of Set 1 : gizo
# City not found. Skipping...
# Processing Record 32 of Set 1 : butaritari
# Processing Record 33 of Set 1 : mataura
# Processing Record 34 of Set 1 : vardo
# City not found. Skipping...
# Processing Record 35 of Set 1 : seoul
# Processing Record 36 of Set 1 : tiarei
# Processing Record 37 of Set 1 : bethel
# City not found. Skipping...
# Processing Record 38 of Set 1 : tasiilaq
# Processing Record 39 of Set 1 : busselton
# City not found. Skipping...
# Processing Record 40 of Set 1 : bambous virieux
# City not found. Skipping...
# Processing Record 41 of Set 1 : dunedin
# Processing Record 42 of Set 1 : vao
# Processing Record 43 of Set 1 : shitanjing
# City not found. Skipping...
# Processing Record 44 of Set 1 : port alfred
# City not found. Skipping...
# Processing Record 45 of Set 1 : port hardy
# Processing Record 46 of Set 1 : berdigestyakh
# Processing Record 47 of Set 1 : cape town
# Processing Record 48 of Set 1 : tautira
# Processing Record 49 of Set 1 : vestmannaeyjar
# Processing Record 50 of Set 1 : east london
# Processing Record 0 of Set 2 : los llanos de aridane
# Processing Record 1 of Set 2 : baryatino
# Processing Record 2 of Set 2 : yamada
# Processing Record 3 of Set 2 : jamestown
# City not found. Skipping...
# Processing Record 4 of Set 2 : punta arenas
# Processing Record 5 of Set 2 : kibala
# Processing Record 6 of Set 2 : kankakee
# Processing Record 7 of Set 2 : yellowknife
# Processing Record 8 of Set 2 : hay river
# Processing Record 9 of Set 2 : barrow
# Processing Record 10 of Set 2 : imeni poliny osipenko
# Processing Record 11 of Set 2 : thompson
# Processing Record 12 of Set 2 : myanaung
# Processing Record 13 of Set 2 : henties bay
# City not found. Skipping...
# Processing Record 14 of Set 2 : upernavik
# Processing Record 15 of Set 2 : sitka
# Processing Record 16 of Set 2 : sambava
# Processing Record 17 of Set 2 : vaini
# Processing Record 18 of Set 2 : cherskiy
# Processing Record 19 of Set 2 : kodinsk
# Processing Record 20 of Set 2 : georgetown
# Processing Record 21 of Set 2 : olive branch
# Processing Record 22 of Set 2 : puerto ayora
# Processing Record 23 of Set 2 : asau
# Processing Record 24 of Set 2 : kochetok
# Processing Record 25 of Set 2 : belaya gora
# City not found. Skipping...
# Processing Record 26 of Set 2 : leh
# Processing Record 27 of Set 2 : cockburn town
# Processing Record 28 of Set 2 : naze
# Processing Record 29 of Set 2 : port hedland
# Processing Record 30 of Set 2 : bettiah
# Processing Record 31 of Set 2 : hobart
# Processing Record 32 of Set 2 : babstovo
# Processing Record 33 of Set 2 : dikson
# Processing Record 34 of Set 2 : guilin
# Processing Record 35 of Set 2 : bluff
# Processing Record 36 of Set 2 : poum
# Processing Record 37 of Set 2 : new norfolk
# Processing Record 38 of Set 2 : goderich
# Processing Record 39 of Set 2 : natal
# Processing Record 40 of Set 2 : avarua
# Processing Record 41 of Set 2 : cidreira
# Processing Record 42 of Set 2 : pisco
# Processing Record 43 of Set 2 : kaitangata
# Processing Record 44 of Set 2 : coihaique
# Processing Record 45 of Set 2 : camacha
# Processing Record 46 of Set 2 : doka
# Processing Record 47 of Set 2 : port elizabeth
# Processing Record 48 of Set 2 : souillac
# City not found. Skipping...
# Processing Record 49 of Set 2 : yerbogachen
# City not found. Skipping...
# Processing Record 50 of Set 2 : hilo
# Processing Record 0 of Set 3 : baruun-urt
# Processing Record 1 of Set 3 : luderitz
# Processing Record 2 of Set 3 : guerrero negro
# City not found. Skipping...
# Processing Record 3 of Set 3 : ust-tarka
# Processing Record 4 of Set 3 : geraldton
# City not found. Skipping...
# Processing Record 5 of Set 3 : kruisfontein
# Processing Record 6 of Set 3 : sao filipe
# Processing Record 7 of Set 3 : antalaha
# Processing Record 8 of Set 3 : aklavik
# Processing Record 9 of Set 3 : katsuura
# Processing Record 10 of Set 3 : fiumicino
# Processing Record 11 of Set 3 : la spezia
# Processing Record 12 of Set 3 : pangnirtung
# Processing Record 13 of Set 3 : nanchang
# Processing Record 14 of Set 3 : lavrentiya
# Processing Record 15 of Set 3 : vallenar
# City not found. Skipping...
# Processing Record 16 of Set 3 : pevek
# Processing Record 36 of Set 4 : panguna
# Processing Record 37 of Set 4 : saint-pierre
# Processing Record 38 of Set 4 : havelock
# Processing Record 39 of Set 4 : hobyo
# Processing Record 40 of Set 4 : sakaiminato
# Processing Record 41 of Set 4 : praia da vitoria
# Processing Record 42 of Set 4 : tezu
# Processing Record 43 of Set 4 : lac du bonnet
# Processing Record 44 of Set 4 : mao
# Processing Record 45 of Set 4 : qaanaaq
# Processing Record 46 of Set 4 : tuatapere
# Processing Record 47 of Set 4 : xining
# Processing Record 48 of Set 4 : norman wells
# Processing Record 49 of Set 4 : bati
# Processing Record 50 of Set 4 : vila franca do campo
# Processing Record 0 of Set 5 : fenyi
# Processing Record 1 of Set 5 : cuamba
# Processing Record 2 of Set 5 : airai
# Processing Record 3 of Set 5 : prince rupert
# Processing Record 4 of Set 5 : beruwala
# Processing Record 5 of Set 5 : kodiak
# City not found. Skipping...
# Processing Record 6 of Set 5 : andros town
# Processing Record 7 of Set 5 : kauhajoki
# Processing Record 8 of Set 5 : bredasdorp
# Processing Record 9 of Set 5 : moree
# Processing Record 10 of Set 5 : desaguadero
# Processing Record 11 of Set 5 : saint anthony
# Processing Record 12 of Set 5 : castro
# Processing Record 13 of Set 5 : padang
# Processing Record 14 of Set 5 : portland
# Processing Record 15 of Set 5 : skjervoy
# Processing Record 16 of Set 5 : sesimbra
# City not found. Skipping...
# Processing Record 17 of Set 5 : kenai
# Processing Record 18 of Set 5 : saint andrews
# Processing Record 19 of Set 5 : komsomolskiy
# Processing Record 20 of Set 5 : wattegama
# Processing Record 21 of Set 5 : marsh harbour
# Processing Record 22 of Set 5 : lodja
# Processing Record 23 of Set 5 : bulach
# Processing Record 24 of Set 5 : batemans bay
# Processing Record 25 of Set 5 : brokopondo
# Processing Record 26 of Set 5 : flin flon
# Processing Record 27 of Set 5 : buctzotz
# Processing Record 28 of Set 5 : mahebourg
# Processing Record 29 of Set 5 : jingdezhen
# City not found. Skipping...
# Processing Record 30 of Set 5 : lompoc
# Processing Record 31 of Set 5 : daugavpils
# Processing Record 32 of Set 5 : tianpeng
# Processing Record 33 of Set 5 : pravda
# Processing Record 34 of Set 5 : maputo
# Processing Record 35 of Set 5 : esperance
# Processing Record 36 of Set 5 : sangamner
# Processing Record 37 of Set 5 : bilma
# Processing Record 38 of Set 5 : haines junction
# Processing Record 39 of Set 5 : fukue
# Processing Record 40 of Set 5 : olafsvik
# Processing Record 41 of Set 5 : big rapids
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 5 : san antonio
# Processing Record 43 of Set 5 : inta
# Processing Record 44 of Set 5 : sonamura
# Processing Record 45 of Set 5 : iqaluit
# Processing Record 46 of Set 5 : nome
# Processing Record 47 of Set 5 : el alto
# Processing Record 48 of Set 5 : den helder
# City not found. Skipping...
# Processing Record 49 of Set 5 : shenjiamen
# Processing Record 50 of Set 5 : nikolskoye
# Processing Record 0 of Set 6 : codrington
# Processing Record 1 of Set 6 : acoua
# Processing Record 2 of Set 6 : pyinmana
# Processing Record 3 of Set 6 : chokurdakh
# City not found. Skipping...
# Processing Record 4 of Set 6 : puerto ayacucho
# Processing Record 5 of Set 6 : forestville
# Processing Record 6 of Set 6 : tonantins
# Processing Record 7 of Set 6 : fairbanks
# Processing Record 8 of Set 6 : provideniya
# Processing Record 9 of Set 6 : amboasary
# Processing Record 10 of Set 6 : denpasar
# Processing Record 11 of Set 6 : ribera
# Processing Record 12 of Set 6 : college
# Processing Record 13 of Set 6 : ulverstone
# City not found. Skipping...
# Processing Record 14 of Set 6 : la ronge
# Processing Record 15 of Set 6 : ilulissat
# Processing Record 16 of Set 6 : kameshkovo
# Processing Record 17 of Set 6 : lazaro cardenas
# Processing Record 18 of Set 6 : egvekinot
# Processing Record 19 of Set 6 : amantea
# Processing Record 20 of Set 6 : sampit
# Processing Record 21 of Set 6 : kavaratti
# Processing Record 22 of Set 6 : bud
# Processing Record 23 of Set 6 : dromolaxia
# Processing Record 24 of Set 6 : shangrao
# Processing Record 25 of Set 6 : zhitnevo
# Processing Record 26 of Set 6 : ous
# Processing Record 27 of Set 6 : sayat
# Processing Record 28 of Set 6 : giyani
# Processing Record 29 of Set 6 : antoing
# Processing Record 30 of Set 6 : chincha alta
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 31 of Set 6 : soyo
# Processing Record 32 of Set 6 : dubti
# Processing Record 33 of Set 6 : shelburne
# Processing Record 34 of Set 6 : najran
# Processing Record 35 of Set 6 : walvis bay
# Processing Record 36 of Set 6 : lasa
# Processing Record 37 of Set 6 : torbay
# Processing Record 38 of Set 6 : nanortalik
# Processing Record 39 of Set 6 : gat
# Processing Record 40 of Set 6 : kirksville
# Processing Record 41 of Set 6 : raudeberg
# Processing Record 42 of Set 6 : namatanai
# Processing Record 43 of Set 6 : yulara
# Processing Record 44 of Set 6 : mosta
# Processing Record 45 of Set 6 : fortuna
# Processing Record 46 of Set 6 : linxia
# Processing Record 47 of Set 6 : port blair
# Processing Record 48 of Set 6 : pembroke
# Processing Record 49 of Set 6 : sanmenxia
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 50 of Set 6 : binga
# Processing Record 0 of Set 7 : catu
# Processing Record 1 of Set 7 : shimanovsk
# Processing Record 2 of Set 7 : bajil
# Processing Record 3 of Set 7 : oksfjord
# Processing Record 4 of Set 7 : shingu
# Processing Record 5 of Set 7 : kahului
# Processing Record 6 of Set 7 : sao joao da barra
# Processing Record 7 of Set 7 : richards bay
# City not found. Skipping...
# Processing Record 8 of Set 7 : north adams
# Processing Record 9 of Set 7 : hami
# Processing Record 10 of Set 7 : nantucket
# Processing Record 11 of Set 7 : labuhan
# Processing Record 12 of Set 7 : palmer
# Processing Record 13 of Set 7 : san miguel
# Processing Record 14 of Set 7 : iberia
# Processing Record 15 of Set 7 : uvira
# Processing Record 16 of Set 7 : sibolga
# Processing Record 17 of Set 7 : christchurch
# Processing Record 18 of Set 7 : frontera
# City not found. Skipping...
# Processing Record 19 of Set 7 : bara
# Processing Record 20 of Set 7 : rockhampton
# Processing Record 21 of Set 7 : klamath falls
# Processing Record 22 of Set 7 : roma
# Processing Record 23 of Set 7 : matata
# Processing Record 24 of Set 7 : cabo san lucas
# City not found. Skipping...
# Processing Record 34 of Set 11 : grootfontein
# Processing Record 35 of Set 11 : san martin
# Processing Record 36 of Set 11 : comodoro rivadavia
# Processing Record 37 of Set 11 : cap malheureux
# Processing Record 38 of Set 11 : bassano del grappa
# Processing Record 39 of Set 11 : aripuana
# Processing Record 40 of Set 11 : takoradi
# Processing Record 41 of Set 11 : manavalakurichi
# Processing Record 42 of Set 11 : dongsheng
# Processing Record 43 of Set 11 : forio
# Processing Record 44 of Set 11 : san alberto
# Processing Record 45 of Set 11 : bokoro
# Processing Record 46 of Set 11 : unirea
# City not found. Skipping...
# Processing Record 47 of Set 11 : kargasok
# Processing Record 48 of Set 11 : luau
# Processing Record 49 of Set 11 : mongoumba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Creating a Final Dataframe with all the data retrieved above using API calls
city_data_df = pd.DataFrame({ 
                "City" : city_name_list,
                "Lat" : lat_list,
                "Lng" : lng_list,
                "Max Temp" : max_temp_list,
                "Humidity" : humidity_list,
                "Cloudiness" : cloudiness_list,
                "Wind Speed" : wind_speed_list,
                "Country" : country_list,
                "Date" : date_list})   
#Saving the whole data into a .csv file
city_data_df.to_csv("D:/Homework/API-Challenge/WeatherPy/Output_data/Cities.csv", index = False)


#Displaying the final Dataframe
city_data_df.head()
# Out:
#                    City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0              Saldanha -33.0117  17.9442     61.93        89         100
# 1             Hithadhoo  -0.6000  73.0833     82.96        70         100
# 2       Puerto Colombia  10.9878 -74.9547     78.80        78           0
# 3  Makkah al Mukarramah  21.4267  39.8261     74.73        53           0
# 4                 Lagoa  39.0500 -27.9833     58.57        81         100
#
#    Wind Speed Country        Date
# 0       12.73      ZA  1616124031
# 1        6.31      MV  1616124199
# 2       12.66      CO  1616124199
# 3        4.74      SA  1616124200
# 4       22.08      PT  1616124201

# %%
#Displaying all the mathematical calculations on numeric columns
city_data_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  559.000000  559.000000  559.000000  559.000000  559.000000  559.000000
# mean    20.966441   18.470397   53.612487   71.756708   53.912343    7.686941
# std     33.591879   91.562549   26.564355   21.034061   40.422427    5.541713
# min    -54.800000 -179.166700  -25.640000    1.000000    0.000000    0.290000
# 25%     -7.299000  -67.561800   35.010000   61.000000    3.000000    3.770000
# 50%     27.629800   18.727100   60.800000   77.000000   67.000000    6.260000
# 75%     48.898650  100.928950   75.190000   88.000000   95.000000   10.360000
# max     78.218600  176.750000  100.400000  100.000000  100.000000   36.860000
#
#                Date
# count  5.590000e+02
# mean   1.616124e+09
# std    1.444089e+02
# min    1.616124e+09
# 25%    1.616124e+09
# 50%    1.616124e+09
# 75%    1.616125e+09
# max    1.616125e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#Checking the highest humidity value 
city_data_df["Humidity"].max()
# Out:
# 100

# %% [markdown]
# As the highest humidity value is 100, Skipping the steps of filtering the humidity column and the whole dataframe

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Creating Latitude vs. Temperature scatter plot
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], facecolor = "steelblue", edgecolor = "black")

# Setting title
plt.title("City Latitude vs. Max Temperature (17/03/2021)")

# Setting x axis label
plt.xlabel("Laitude")

# Setting y axis label
plt.ylabel("Max Temperature (F)")

# Setting grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Saving the plotted figure as .pngs
plt.savefig("D:/Homework/API-Challenge/WeatherPy/Output_data/Latitude vs Max Temperature.png")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Creating Latitude vs. Humidity scatter plot
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], facecolor = "steelblue", edgecolor = "black")

# Setting title
plt.title("City Latitude vs. Max Temperature (17/03/2021)")

# Setting x axis label
plt.xlabel("Laitude")

# Setting y axis label
plt.ylabel("Humidity (%)")

# Setting grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Saving the plotted figure as .pngs
plt.savefig("D:/Homework/API-Challenge/WeatherPy/Output_data/Latitude vs Humidity.png")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Creating Latitude vs. Cloudiness scatter plot
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], facecolor = "steelblue", edgecolor = "black")

# Setting title
plt.title("City Latitude vs. Max Temperature (17/03/2021)")

# Setting x axis label
plt.xlabel("Laitude")

# Setting y axis label
plt.ylabel("Cloudiness (%)")

# Setting grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Saving the plotted figure as .pngs
plt.savefig("D:/Homework/API-Challenge/WeatherPy/Output_data/Latitude vs Cloudiness.png")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Creating Latitude vs. Cloudiness scatter plot
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], facecolor = "steelblue", edgecolor = "black")

# Setting title
plt.title("City Latitude vs. Max Temperature (17/03/2021)")

# Setting x axis label
plt.xlabel("Laitude")

# Setting y axis label
plt.ylabel("Wind Speed (mph)")

# Setting grid line
plt.grid(linestyle='-', linewidth=1, alpha = 0.5)

# Saving the plotted figure as .pngs
plt.savefig("D:/Homework/API-Challenge/WeatherPy/Output_data/Latitude vs Wind Speed.png")

# %% [markdown]
# ## Linear Regression

# %%
#Creating the northern and southern hemispheres using the Latitude 
northern_hemisphere = city_data_df.loc[city_data_df["Lat"]>=0]
southern_hemisphere = city_data_df.loc[city_data_df["Lat"]<0]

# %%
# Defining a  function for calculating linear regression and scatter plot for all the relationships
def linear_regression(x,y):
    print(f"The r-squared is : {round(st.pearsonr(x, y)[0],2)}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x, y)
    plt.plot(x,regress_values,"r-")
    return line_eq

# Defining a fuction for annotating the regression line
def annotate(line_eq, a, b):
    plt.annotate(line_eq,(a,b),fontsize=15,color="red")

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Calling the Line Regression function for the analysis
line_equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Max Temp"])

# Calling annotation function
annotate(line_equation,0,0)

# Setting a title
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Setting xlabel
plt.xlabel("Latitude")

# Setting ylabel
plt.ylabel("Max Temp (F)")

# Setting the plotted figure as .pngs
plt.savefig("D:/Homework/API-Challenge/WeatherPy/Output_data/Northern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : -0.88

# %% [markdown]
# There is a very strong negative correlation between Max Temperature and Latitude values in the Northern Hemisphere.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Calling the Line Regression function for the analysis
line_equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Max Temp"])

# Calling annotation function
annotate(line_equation, -30, 50)

# Set a title
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression")

# Set xlabel
plt.xlabel("Latitude")

# Set ylabel
plt.ylabel("Max Temp (F)")

# Setting the plotted figure as .pngs
plt.savefig("D:/Homework/API-Challenge/WeatherPy/Output_data/Southern Hemisphere - Max Temp vs. Latitude Linear Regression.png")
# Out:
# The r-squared is : 0.53

# %% [markdown]
# The Max Temperature and Latitude values in the Southern Hemisphere are moderately correlated

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Calling the Line Regression function for the analysis
line_equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Humidity"])

# Calling annotation function
annotate(line_equation,45,50)

# Setting a title
plt.title("Northern Hemisphere - Humidity (%) vs. Latitude  Regression")

# Setting xlabel
plt.xlabel("Latitude")

# Setting ylabel
plt.ylabel("Humidity")

# Setting the plotted figure as .pngs
plt.savefig("D:/Homework/API-Challenge/WeatherPy/Output_data/Northern Hemisphere - Humidity (%) vs. Latitude  Regression.png")
# Out:
# The r-squared is : 0.27

# %% [markdown]
# There is weak correlation between Humidity and Latitude values in the Northern Hemisphere

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Calling the Line Regression function for the analysis
line_equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Humidity"])

# Calling annotation function
annotate(line_equation,-50,60)

# Setting a title
plt.title("Southern Hemisphere - Humidity (%) vs. Latitude  Regression")

# Setting xlabel
plt.xlabel("Latitude")

# Setting ylabel
plt.ylabel("Humidity")

# Setting the plotted figure as .pngs
plt.savefig("D:/Homework/API-Challenge/WeatherPy/Output_data/Southern Hemisphere - Humidity (%) vs. Latitude  Regression.png")
# Out:
# The r-squared is : 0.32

# %% [markdown]
# There is weak positive correlation between Humidity and Latitude in the Southern Hemisphere

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Calling the Line Regression function for the analysis
line_equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Cloudiness"])

# Calling  annotation function
annotate(line_equation,45,50)

# Setting a title
plt.title("Northern Hemisphere - Cloudiness (%) vs. Latitude  Regression")

# Setting xlabel
plt.xlabel("Latitude")

# Setting ylabel
plt.ylabel("Cloudiness")

# Setting the plotted figure as .pngs
plt.savefig("D:/Homework/API-Challenge/WeatherPy/Output_data/Northern Hemisphere - Cloudiness (%) vs. Latitude  Regression.png")
# Out:
# The r-squared is : 0.18

# %% [markdown]
# There is a weak postive correlation between Cloudiness and Latitude values in the Northern Hemisphere

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Calling the Line Regression function for the analysis
line_equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Cloudiness"])

# Calling  annotation function
annotate(line_equation,-55,50)

# Setting a title
plt.title("Southern Hemisphere - Cloudiness (%) vs. Latitude  Regression")

# Setting xlabel
plt.xlabel("Latitude")

# Setting ylabel
plt.ylabel("Cloudiness")

# Setting the plotted figure as .pngs
plt.savefig("D:/Homework/API-Challenge/WeatherPy/Output_data/Southern Hemisphere - Cloudiness (%) vs. Latitude  Regression.png")
# Out:
# The r-squared is : 0.35

# %% [markdown]
# There is a weak positive correlation between Cloudiness and Latitude Values in the Southern Hemisphere

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Calling the Line Regression function for the analysis
line_equation = linear_regression(northern_hemisphere["Lat"], northern_hemisphere["Wind Speed"])

# Calling  annotation function
annotate(line_equation,40,30)

# Setting a title
plt.title("Northern Hemisphere - Wind Speed  (%) vs. Latitude  Regression")

# Setting xlabel
plt.xlabel("Latitude")

# Setting ylabel
plt.ylabel("Wind Speed (mph)")

# Setting the plotted figure as .pngs
plt.savefig("D:/Homework/API-Challenge/WeatherPy/Output_data/Northern Hemisphere - Wind Speed  (%) vs. Latitude  Regression.png")
# Out:
# The r-squared is : 0.19

# %% [markdown]
# There is a weak positive correlation between Wind Speed and Latitude values in the Northern Hemisphere

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Calling the Line Regression function for the analysis
line_equation = linear_regression(southern_hemisphere["Lat"], southern_hemisphere["Wind Speed"])

# Calling  annotation function
annotate(line_equation,-48,17)

# Setting a title
plt.title("Southern Hemisphere -  Wind Speed (mph) vs. Latitude  Regression")

# Setting xlabel
plt.xlabel("Latitude")

# Setting ylabel
plt.ylabel("Wind Speed ")

# Setting the plotted figure as .pngs
plt.savefig("D:/Homework/API-Challenge/WeatherPy/Output_data/Southern Hemisphere -  Wind Speed (mph) vs. Latitude  Regression.png")
# Out:
# The r-squared is : -0.29

# %% [markdown]
# There is a weak negative correlation between Wind Speed and Latitude values in the Southern Hemisphere
